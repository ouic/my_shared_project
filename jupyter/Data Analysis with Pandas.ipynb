# %% [markdown]
# # Pandas Cheat Sheet
#
# https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf

# %% [markdown]
# ## Built-in Functions :
#
# - https://docs.python.org/3/library/functions.html

# %% [markdown]
# ## calling a method on the `str`:
#
# - https://docs.python.org/3/library/stdtypes.html#string-methods

# %% [markdown]
# ## Dataset Search :
#
# - https://datasetsearch.research.google.com/
# - https://www.kaggle.com
# - https://www.kaggle.com/datasets?sort=votes&datasetsOnly=true

# %% [markdown]
# ## Pandas
# (better than excel for Python):
# - handling large datasets (no limit on number of rows)
# - combine multiple files
# - pull data from APIs
# - Python

# %% [markdown]
# Load data directly from a CSV file on disk :

# %%
import pandas as pd
a_dataframe = pd.read_csv(FILEPATH)

# %% [markdown]
# Load data from pultiple other sources :
# - https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html

# %% [markdown]
# ## Seaborn
# Data visualization with Seaborn (based on matplotlib) :
# - https://seaborn.pydata.org/

# %%
import seaborn as sns

# %% [markdown]
# New York City Airbnb Open Data
# Let's use this example :
# - https://www.kaggle.com/dgomonov/new-york-city-airbnb-open-data

# %% [markdown]
# ## Pandas

# %%
import pandas as pd

# %%
# change the Current Working Directory using os.chdir()
import os
from pathlib import Path
os.chdir('E:\\Eric\\Programmation\\Python\\OUIC\\Data Analysis')
Path.cwd()
# Out:
# WindowsPath('E:/Eric/Programmation/Python/OUIC/Data Analysis')

# %%
import zipfile, os
from pathlib import Path
p = Path('E:\\Eric\\Programmation\\Python\\OUIC\\Data Analysis')
exampleZip = zipfile.ZipFile(p / 'archive.zip')
exampleZip.extractall()
exampleZip.close()

# %%
print(os.listdir())
# Out:
# ['data']

# %% [markdown]
# ## DataFrame
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html

# %%
# listings_df = listing data frame
listings_df = pd.read_csv('data/AB_NYC_2019.csv', delimiter=',')

# %% [markdown]
# ## Methods
# - `.shape`
# - `.columns`
# - `.dtypes`
# - `.head()` / `.tail()`

# %%
listings_df.shape # returns a Tuple with number of rows and columns
# Out:
# (48895, 16)

# %%
listings_df.columns # returns a List of the names of the columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
listings_df.dtypes # returns the names of the columns and the types of the columns
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %%
listings_df.head() # returns the table of the 5 first rows of the dataset
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
listings_df.tail() # returns the table of the 5 last rows of the dataset
# Out:
#              id                                               name   host_id  \
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# 48890        Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891        Marisol            Brooklyn            Bushwick  40.70184
# 48892  Ilgar & Aysel           Manhattan              Harlem  40.81475
# 48893            Taz           Manhattan      Hell's Kitchen  40.75751
# 48894     Christophe           Manhattan      Hell's Kitchen  40.76404
#
# ...

# %%
listings_df.head(3) # returns the table of the 3 first rows of the dataset
# Out:
#      id                                 name  host_id  host_name  \
# 0  2539   Clean & quiet apt home by the park     2787       John
# 1  2595                Skylit Midtown Castle     2845   Jennifer
# 2  3647  THE VILLAGE OF HARLEM....NEW YORK !     4632  Elisabeth
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 2           Manhattan        Harlem  40.80902  -73.94190     Private room
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    149               1                  9  2018-10-19               0.21
# 1    225               1                 45  2019-05-21               0.38
# 2    150               3                  0         NaN                NaN
#
#    calculated_host_listings_count  availability_365
# ...

# %% [markdown]
# ## cleaning data
# - show how many nulls are found in each columns with :
#
#     - `listing_df.isnull().sum()`
#
#
# - drop some columns not relevant enough four our analysis with .drop() and inplace=True to implement the change in the original dataframe :
#
#     - `columns_to_drop = ['id', 'host_name', 'last_review']
#     listings_df.drop(columns_to_drop, axis="columns", inplace=True)`

# %%
listings_df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
columns_to_drop = ['id', 'host_name', 'last_review']
listings_df.drop(columns_to_drop, axis="columns", inplace=True)

# %%
listings_df.head() # returns the table of the 5 first rows of the dataset
# Out:
#                                                name  host_id  \
# 0                Clean & quiet apt home by the park     2787
# 1                             Skylit Midtown Castle     2845
# 2               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3                   Cozy Entire Floor of Brownstone     4869
# 4  Entire Apt: Spacious Studio/Loft by central park     7192
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 2           Manhattan        Harlem  40.80902  -73.94190     Private room
# 3            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
# 4           Manhattan   East Harlem  40.79851  -73.94399  Entire home/apt
#
#    price  minimum_nights  number_of_reviews  reviews_per_month  \
# 0    149               1                  9               0.21
# ...

# %% [markdown]
# ## NaN
# To remove `NaN` from the `reviews _per_month` column :
# - `listings_df.fillna({'reviews_per_month': 0}, inplace=True)`
#
# or
# - `listings_df.dropna({'reviews_per_month'}, inplace=True)`

# %%
listings_df.fillna({'reviews_per_month': 0}, inplace=True)

# %%
listings_df.head() # returns the table of the 5 first rows of the dataset
# Out:
#                                                name  host_id  \
# 0                Clean & quiet apt home by the park     2787
# 1                             Skylit Midtown Castle     2845
# 2               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3                   Cozy Entire Floor of Brownstone     4869
# 4  Entire Apt: Spacious Studio/Loft by central park     7192
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 2           Manhattan        Harlem  40.80902  -73.94190     Private room
# 3            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
# 4           Manhattan   East Harlem  40.79851  -73.94399  Entire home/apt
#
#    price  minimum_nights  number_of_reviews  reviews_per_month  \
# 0    149               1                  9               0.21
# ...

# %% [markdown]
# ## Filter columns and rows
# - filter columns by name :
#     -  `listings_df['name']` 1 column
#     -  `listings_df[['name', 'neighbourhood_group', 'price']]` several columns
#
#
# - filter rows by index :
#     -  `listings_df[5:10]`
#
#
# - combination of rows and colums filter :
#     -   `listings_df[5:10][['name', 'neighbourhood_group', 'price']]`

# %%
listings_df[5:10][['name', 'neighbourhood_group', 'price']]
# Out:
#                                         name neighbourhood_group  price
# 5  Large Cozy 1 BR Apartment In Midtown East           Manhattan    200
# 6                            BlissArtsSpace!            Brooklyn     60
# 7           Large Furnished Room Near B'way            Manhattan     79
# 8         Cozy Clean Guest Room - Family Apt           Manhattan     79
# 9         Cute & Cozy Lower East Side 1 bdrm           Manhattan    150

# %% [markdown]
# ## Boolean Indexing
# - filter rows by value :
#     -  `listings_df[listings_df['price'] < 100]`

# %%
listings_df[listings_df['price'] < 100]
# Out:
#                                                     name    host_id  \
# 3                        Cozy Entire Floor of Brownstone       4869
# 4       Entire Apt: Spacious Studio/Loft by central park       7192
# 6                                        BlissArtsSpace!       7356
# 7                       Large Furnished Room Near B'way        8967
# 8                     Cozy Clean Guest Room - Family Apt       7490
# ...                                                  ...        ...
# 48889                                 QUIT PRIVATE HOUSE  107716952
# 48890    Charming one bedroom - newly renovated rowhouse    8232441
# 48891      Affordable room in Bushwick/East Williamsburg    6570630
# 48893               43rd St. Time Square-cozy single bed   30985759
# 48894  Trendy duplex in the very heart of Hell's Kitchen   68119814
#
#       neighbourhood_group       neighbourhood  latitude  longitude  \
# 3                Brooklyn        Clinton Hill  40.68514  -73.95976
# ...

# %% [markdown]
# ## Exploratory Data Analysis
# - Ask questions to the dataset :
#     - What are the 10 most reviewed listings ?
#         - `listings_df.nlargest(10, 'number_of_reviews')`
#     - What are the NY neighbourhood groups with listings ?
#         - `listings_df['neighbourhood_group'].unique()`
#     - How many listings per neighbourhoods group ?
#         - `listings_df['neighbourhood_group'].value_counts()`
#     - What are the top 10 neighbourhoods with Airbnb listings ?
#         - `listings_df['neighbourhood'].value_counts().head(10)`

# %%
listings_df.nlargest(10, 'number_of_reviews')
# Out:
#                                                     name   host_id  \
# 11759                            Room near JFK Queen Bed  47621202
# 2031                          Great Bedroom in Manhattan   4734398
# 2030                      Beautiful Bedroom in Manhattan   4734398
# 2015                        Private Bedroom in Manhattan   4734398
# 13495                            Room Near JFK Twin Beds  47621202
# 10623                  Steps away from Laguardia airport  37312959
# 1879            Manhattan Lux Loft.Like.Love.Lots.Look !   2369681
# 20403  Cozy Room Family Home LGA Airport NO CLEANING FEE  26432133
# 4870                  Private brownstone studio Brooklyn  12949460
# 471                      LG Private Room/Family Friendly    792159
#
#       neighbourhood_group    neighbourhood  latitude  longitude  \
# 11759              Queens          Jamaica  40.66730  -73.76831
# 2031            Manhattan           Harlem  40.82085  -73.94025
# ...

# %%
listings_df['neighbourhood_group'].unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %%
listings_df['neighbourhood_group'].value_counts()
# Out:
# Manhattan        21661
# Brooklyn         20104
# Queens            5666
# Bronx             1091
# Staten Island      373
# Name: neighbourhood_group, dtype: int64

# %%
listings_df['neighbourhood'].value_counts().head(10)
# Out:
# Williamsburg          3920
# Bedford-Stuyvesant    3714
# Harlem                2658
# Bushwick              2465
# Upper West Side       1971
# Hell's Kitchen        1958
# East Village          1853
# Upper East Side       1798
# Crown Heights         1564
# Midtown               1545
# Name: neighbourhood, dtype: int64

# %% [markdown]
# ## Graphical representation
# - Plot a barchart with `matplotlib` calling `.plot(kind='bar')` directly on the dataframe

# %%
listings_df['neighbourhood'].value_counts().head(10).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Graphical representation
# - No need for a `value_counts()` with `seaborn`, we can just use a `Countplot`
# https://seaborn.pydata.org/generated/seaborn.countplot.html
#
#     - `sns.countplot(data=listings_df, x='neighbourhood_group')`

# %%
import seaborn as sns
sns.countplot(data=listings_df, x='neighbourhood_group')
# Out:
# <AxesSubplot:xlabel='neighbourhood_group', ylabel='count'>

# %%
listings_df['neighbourhood_group'].value_counts().index
# Out:
# Index(['Manhattan', 'Brooklyn', 'Queens', 'Bronx', 'Staten Island'], dtype='object')

# %%
order = listings_df['neighbourhood_group'].value_counts().index
sns.countplot(data=listings_df, x='neighbourhood_group', order=order)
# Out:
# <AxesSubplot:xlabel='neighbourhood_group', ylabel='count'>

# %% [markdown]
# - Ask questions to the dataset :
#     - What is the influence of neighbourhood_group on room type ?
#     FYI, here are the room types :
#         - `listings_df['room_type'].unique()`
#
#         - `sns.countplot(data=listings_df, x='neighbourhood_group', hue='room_type')`

# %%
listings_df['room_type'].unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room'], dtype=object)

# %%
sns.countplot(data=listings_df, x='neighbourhood_group', hue='room_type')
# Out:
# <AxesSubplot:xlabel='neighbourhood_group', ylabel='count'>

# %% [markdown]
# - Ask questions to the dataset :
#     - What is the distribution of flat prices ?
#     We can use a Displot : https://seaborn.pydata.org/generated/seaborn.displot.html
#         - `sns.displot(listings_df['price'])`

# %%
sns.displot(listings_df['price'])

# %%
affordable_df = listings_df[listings_df['price'] <= 500]
sns.displot(affordable_df['price'])

# %%
sns.distplot(affordable_df['price'])
# Out:
# P:\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
# calculer la moyenne
print(listings_df['price'].mean())
print(affordable_df['price'].mean())
# Out:
# 152.7206871868289
# 131.53056362458466

# %% [markdown]
# - Ask questions to the dataset :
#     - What is the distribution of flat prices on the neighbourhood group ?
#     We can use a Violinplot : https://seaborn.pydata.org/generated/seaborn.violinplot.html
#         - `sns.violinplot(data=affordable_df, x='neighbourhood_group', y='price')`

# %%
sns.violinplot(data=affordable_df, x='neighbourhood_group', y='price')
# Out:
# <AxesSubplot:xlabel='neighbourhood_group', ylabel='price'>

# %%
# make a bigger picture
from matplotlib import pyplot as plt
plt.figure(figsize=(15, 8))
sns.violinplot(data=affordable_df, x='neighbourhood_group', y='price')
# Out:
# <AxesSubplot:xlabel='neighbourhood_group', ylabel='price'>

# %% [markdown]
# - Ask questions to the dataset :
#     - Can we plot the listings on a map ?
#     Back to `matplotlib`, we can use scatterplot : https://seaborn.pydata.org/generated/seaborn.scatterplot.html
#         - `affordable_df.plot(
#     kind='scatter',
#     x='longitude',
#     y='latitude',
#     c='price',
#     cmap='inferno',
#     colorbar=True,
#     alpha=0.8,
#     figsize=(12,8))`

# %%
affordable_df.plot(
    kind='scatter',
    x='longitude',
    y='latitude',
    c='price',
    cmap='inferno',
    colorbar=True,
    alpha=0.8,
    figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>

# %% [markdown]
# - Ask questions to the dataset :
#     - Can we add MYC map underneath ?
#
#
# `
# from matplotlib import pyplot as plt
# import urllib
# i = urllib.request.urlopen('https://upload.wikipedia.org/wikipedia/commons/e/ec/Neighbourhoods_New_York_City_Mapp.PNG')
# plt.imshow(plt.imread(i), zorder=0, extent=[-74.258, -73.7, 40.49, 40.92])
# ax = plt.gca()
# affordable_df.plot(
#     kind='scatter',
#     x='longitude',
#     y='latitude',
#     c='price',
#     cmap='inferno',
#     colorbar=True,
#     alpha=0.8,
#     figsize=(12,8))`

# %%
from matplotlib import pyplot as plt
import urllib
i = urllib.request.urlopen('https://upload.wikimedia.org/wikipedia/commons/e/ec/Neighbourhoods_New_York_City_Map.PNG')
plt.imshow(plt.imread(i), zorder=0, extent=[-74.258, -73.7, 40.49, 40.92])
ax = plt.gca()            
affordable_df.plot(
    kind='scatter',
    x='longitude',
    y='latitude',
    c='price',
    cmap='inferno',
    colorbar=True,
    alpha=0.8,
    figsize=(12,8))

# %% [markdown]
# ![image.png](attachment:image.png)
